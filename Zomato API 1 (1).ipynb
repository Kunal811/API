# %%
#395043d44540d04fc5104aaee536695e
import json
import requests

# %%
#Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
header={'user-key':'395043d44540d04fc5104aaee536695e'}
r=requests.get('https://developers.zomato.com/api/v2.1/cuisines',params={'city_id':1},headers=header)
d=r.json()
d
# Out:
# {'cuisines': [{'cuisine': {'cuisine_id': 1035, 'cuisine_name': 'Afghan'}},
#   {'cuisine': {'cuisine_id': 152, 'cuisine_name': 'African'}},
#   {'cuisine': {'cuisine_id': 1, 'cuisine_name': 'American'}},
#   {'cuisine': {'cuisine_id': 2, 'cuisine_name': 'Andhra'}},
#   {'cuisine': {'cuisine_id': 4, 'cuisine_name': 'Arabian'}},
#   {'cuisine': {'cuisine_id': 175, 'cuisine_name': 'Armenian'}},
#   {'cuisine': {'cuisine_id': 3, 'cuisine_name': 'Asian'}},
#   {'cuisine': {'cuisine_id': 165, 'cuisine_name': 'Assamese'}},
#   {'cuisine': {'cuisine_id': 292, 'cuisine_name': 'Awadhi'}},
#   {'cuisine': {'cuisine_id': 193, 'cuisine_name': 'BBQ'}},
#   {'cuisine': {'cuisine_id': 5, 'cuisine_name': 'Bakery'}},
#   {'cuisine': {'cuisine_id': 227, 'cuisine_name': 'Bar Food'}},
#   {'cuisine': {'cuisine_id': 132, 'cuisine_name': 'Belgian'}},
#   {'cuisine': {'cuisine_id': 10, 'cuisine_name': 'Bengali'}},
#   {'cuisine': {'cuisine_id': 270, 'cuisine_name': 'Beverages'}},
# ...

# %%
for i in d['cuisines']:
    if (i.get('cuisine').get('cuisine_name')=='Mexican'):
        print(i.get('cuisine').get('cuisine_id'))
#Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
# Out:
# 73

# %%
header={'user-key':'395043d44540d04fc5104aaee536695e'}
r=requests.get('https://developers.zomato.com/api/v2.1/geocode',headers=header,params={'lat':28.6304,'lon':77.2177})
d=r.json()
print(d['location']['entity_id'],d['location']['entity_type'])
# Out:
# 104 subzone

# %%
header={'user-key':'395043d44540d04fc5104aaee536695e'}
par={'entity_id':104,'entity_type':'subzone','count':10,'cuisines':'73','sort':'rating','category':'6'}
f=requests.get('https://developers.zomato.com/api/v2.1/search',params=par,headers=header)
d=f.json()
d
# Out:
# {'results_found': 5,
#  'results_start': 0,
#  'results_shown': 5,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18729557},
#     'apikey': '395043d44540d04fc5104aaee536695e',
#     'id': '18729557',
#     'name': 'Xero Degrees',
#     'url': 'https://www.zomato.com/ncr/xero-degrees-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'L-23/9, Middle Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6343423459',
#      'longitude': '77.2213641554',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Cafe, Fast Food, Beverages',
#     'timings': '12:30PM to 11PM (Mon-Sun)',
#     'average_cost_for_two': 750,
#     'price_range': 2,
# ...

# %%
for i in d['restaurants']:
    print(i.get('restaurant').get('name'),i.get('restaurant').get('user_rating').get('aggregate_rating'),i.get('restaurant').get('R').get('res_id'))
# Out:
# Xero Degrees 4.4 18729557
# The Art House Bar n Cafe 4.2 18863766
# Chaayos - Meri Wali Chai 4.1 18237315
# Cafe Delhi Heights 4.0 18579363
# Cafe Coffee Day - The Square 3.8 303034

# %%
header={'user-key':'395043d44540d04fc5104aaee536695e'}
par={'res_id':18729557}
r=requests.get('https://developers.zomato.com/api/v2.1/reviews',headers=header,params=par)
d=r.json()
d
# Out:
# {'reviews_count': 1211,
#  'reviews_start': 0,
#  'reviews_shown': 5,
#  'user_reviews': [{'review': {'rating': 4,
#     'review_text': '',
#     'id': 49023261,
#     'rating_color': '5BA829',
#     'review_time_friendly': 'yesterday',
#     'rating_text': 'Great!',
#     'timestamp': 1587559022,
#     'likes': 0,
#     'user': {'name': 'Hina Vohra',
#      'foodie_color': 'ffae4f',
#      'profile_url': 'https://www.zomato.com/users/hina-vohra-42859135?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/47c/fe104d10c7f90b027af53c0e8ce1e47c.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/42859135'},
#     'comments_count': 0}},
#   {'review': {'rating': 4,
#     'review_text': '',
#     'id': 49020256,
#     'rating_color': '5BA829',
#     'review_time_friendly': 'yesterday',
#     'rating_text': 'Great!',
#     'timestamp': 1587501674,
#     'likes': 0,
# ...

# %%
for i in d['user_reviews']:
    print(i['review'].get('user').get('name'),i['review'].get('rating'),i['review'].get('review_text'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-8a9495486895> in <module>
# ----> 1 for i in d['user_reviews']:
#       2     print(i['review'].get('user').get('name'),i['review'].get('rating'),i['review'].get('review_text'))
#       3
#
# KeyError: 'user_reviews'

# %%
#28.6915
#77.2024
import json
import requests
header={'user-key':'395043d44540d04fc5104aaee536695e'}
# par={'entity_id':646,'entity_type':'subzone'}
par={'res_id':18241524}
r=requests.get('https://developers.zomato.com/api/v2.1/restaurant',headers=header,params=par)
d=r.json()
d
# Out:
# {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#   'res_id': 18241524},
#  'apikey': '395043d44540d04fc5104aaee536695e',
#  'id': '18241524',
#  'name': '736 A.D.',
#  'url': 'https://www.zomato.com/ncr/736-a-d-vijay-nagar-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#  'location': {'address': 'G-15/B, Vijay Nagar, New Delhi',
#   'locality': 'Vijay Nagar',
#   'city': 'New Delhi',
#   'city_id': 1,
#   'latitude': '28.6942619387',
#   'longitude': '77.2036920860',
#   'zipcode': '110009',
#   'country_id': 1,
#   'locality_verbose': 'Vijay Nagar, New Delhi'},
#  'switch_to_order_menu': 0,
#  'cuisines': 'North Indian, Continental, Italian, Chinese',
#  'timings': '11 AM to 1 AM',
#  'average_cost_for_two': 1400,
#  'price_range': 3,
#  'currency': 'Rs.',
#  'highlights': ['Dinner',
#   'Cash',
#   'Takeaway Available',
#   'Debit Card',
#   'Lunch',
#   'Delivery',
#   'Credit Card',
#   'Live Sports Screening',
#   'Fullbar',
# ...

# %%
#28.6915
#77.2024
import json
import requests
header={'user-key':'395043d44540d04fc5104aaee536695e'}
# par={'entity_id':646,'entity_type':'subzone'}
par={'res_id':18241524}
r=requests.get('https://developers.zomato.com/api/v2.1/reviews',headers=header,params=par)
d=r.json()
d
# Out:
# {'reviews_count': 1484,
#  'reviews_start': 0,
#  'reviews_shown': 5,
#  'user_reviews': [{'review': {'rating': 4,
#     'review_text': '',
#     'id': 49026612,
#     'rating_color': '5BA829',
#     'review_time_friendly': 'yesterday',
#     'rating_text': 'Great!',
#     'timestamp': 1587631054,
#     'likes': 0,
#     'user': {'name': 'Lavanya Kv',
#      'zomato_handle': 'feed_your_feeds',
#      'foodie_color': 'f58552',
#      'profile_url': 'https://www.zomato.com/feed_your_feeds?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#      'profile_image': 'https://b.zmtcdn.com/data/user_profile_pictures/036/d18609b5c673757bdda4c15c5c141036.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#      'profile_deeplink': 'zomato://u/70805218'},
#     'comments_count': 0}},
#   {'review': {'rating': 4,
# ...

# %%
for i in d['user_reviews']:
    print(i['review'].get('user').get('name'),i['review'].get('rating'),i['review'].get('review_text'))
# Out:
# Lavanya Kv 4
# Foodieszonee 4 It’s a very nice place to hangout and has a very nice ambience, great dj and the food was very good must try white sauce pasta.  Good and fast service also reasonable price.
# Prerana Verma 5
# Namankhosla23 4 The food here was very good. They had a good variety. Ambiance was very cosy and perfect for a date. Must try place for good and shakes.   Food 4/5 Staff 3/5
# Sonali Garg 5 Last week my exams got over and we all friends decided to visit here. As 736 AD is a very good restaurant so we visited here. The menu consists of many varieties of dishes and we selected some common dishes like: 1. Veg platter 2. Veg manchurian  3. Tandoori momos  4. Cheese nachos 5. Salt and pepper 6. Mocktails and shakes  The food here was so delicious and wonderful. Ambiance was beautiful and service was at its best. I really enjoyed there and I highly recommend this restaurant to visit once.

# %%
#28.6977
#77.1406
import json
import requests
header={'user-key':'395043d44540d04fc5104aaee536695e'}
par={'lat':28.6977,'lon':77.1406,'cuisines':'193','sort':'rating','count':10,'radius':4000}
r=requests.get('https://developers.zomato.com/api/v2.1/search',headers=header,params=par)
d=r.json()
d
# Out:
# {'results_found': 127,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18317477},
#     'apikey': '395043d44540d04fc5104aaee536695e',
#     'id': '18317477',
#     'name': 'The Barbeque Company',
#     'url': 'https://www.zomato.com/ncr/the-barbeque-company-karkardooma-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '4, Hargovind Enclave, Opposite Shanti Mukund Hospital, Karkardooma, New Delhi',
#      'locality': 'Karkardooma',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6461757659',
#      'longitude': '77.3010100052',
#      'zipcode': '110092',
#      'country_id': 1,
#      'locality_verbose': 'Karkardooma, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Chinese, Continental, BBQ',
# ...

# %%
for i in d['restaurants']:
    print(i['restaurant'].get('name'),i['restaurant'].get('user_rating').get('aggregate_rating'),i['restaurant'].get('R').get('res_id'),i['restaurant'].get('location').get('locality'))
# Out:
# The Barbeque Company 4.5 18317477 Karkardooma
# Themis Barbecue House 4.5 18204820 Netaji Subhash Place
# Delish BBQ 4.5 18424869 Jaipuria Plaza, Sector 26, Noida
# Barbeque Nation 4.5 18586005 Grand Mall, MG Road
# Delhi Barbeque 4.5 18964418 Mahipalpur
# Barbeque Nation 4.3 301489 Connaught Place
# Barbeque Nation 4.3 18616096 Beta 2
# Castle's Barbeque 4.3 18624001 Pacific Mall, Tagore Garden
# Barbeque Nation 4.3 300721 Vasant Kunj
# Barbeque Nation 4.3 18789249 Sector 62

# %%
#18204820 
import json
import requests
header={'user-key':'395043d44540d04fc5104aaee536695e'}
# par={'entity_id':646,'entity_type':'subzone'}
par={'res_id':18204820}
r=requests.get('https://developers.zomato.com/api/v2.1/reviews',headers=header,params=par)
d=r.json()
for i in d['user_reviews']:
    print(i['review'].get('user').get('name'),i['review'].get('rating'),i['review'].get('review_text'))
# Out:
# Medhavi 5 Enjoyed a wide range of dishes at this buffet outlet with aesthetic interiors and designer exteriors. Scrumptious barbeque starters with grilled chicken,fish tikka in skewers on the table. Sipped on a variety of mocktails plus the singer was there to entertain throughout our time there. The main course dishes were made very well with excellent sea food, dum biryani , paneer dishes, types of breads and exquisite desserts to choose from namely white chocolate brownie , pineapple pastries , truffle cake and cut fruits. Would definitely recommend to one and all.
# ...

# %%
import json
import requests
header={'user-key':'395043d44540d04fc5104aaee536695e'}
r=requests.get('https://developers.zomato.com/api/v2.1/cuisines',headers=header,params={'city_id':1})
d=r.json()
l=['BBQ', 'Malwani', 'German', 'Cajun']
for i in d['cuisines']:
    if(i['cuisine'].get('cuisine_name') in l):
        print('Dataset incomplete')
        break
# Out:
# Dataset incomplete
