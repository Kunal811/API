# %%
#Client ID:a0dded788ce508ce9865
#Client Secret:4dc37b0ab100a7caba4f34fe2a648810c0d3804a
import requests
import json

# %%
dat={'client_id':'a0dded788ce508ce9865','redirect_uri':'https://www.google.com/','scope':'repo','state':'yokb'}
data=requests.get('https://github.com/login/oauth/authorize',params=dat)
data.url
# Out:
# 'https://github.com/login?client_id=a0dded788ce508ce9865&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3Da0dded788ce508ce9865%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%252F%26scope%3Drepo%26state%3Dyokb'

# %%
#f6330a7df2ce5b475930
dat={'client_id':'a0dded788ce508ce9865','client_secret':'4dc37b0ab100a7caba4f34fe2a648810c0d3804a','code':'9c351da82b9da78b09ab','redirect_uri':'https://www.google.com/','state':'yokb'}
req=requests.post('https://github.com/login/oauth/access_token',data=dat)
req.text
# Out:
# 'access_token=bb68b5dc01d784a1a596d6666c3c133e8f9205a0&scope=repo&token_type=bearer'

# %%
header={'Authorization':'bearer bb68b5dc01d784a1a596d6666c3c133e8f9205a0'}
resp=requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',data={'type':'all'})
d=resp.json()
d
# Out:
# [{'id': 68499062,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2ODQ5OTA2Mg==',
#   'name': 'SmoothScrollJs',
#   'full_name': 'CodingNinjasCodes/SmoothScrollJs',
#   'private': False,
#   'owner': {'login': 'CodingNinjasCodes',
#    'id': 22269960,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMjY5OTYw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22269960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodingNinjasCodes',
#    'html_url': 'https://github.com/CodingNinjasCodes',
#    'followers_url': 'https://api.github.com/users/CodingNinjasCodes/followers',
#    'following_url': 'https://api.github.com/users/CodingNinjasCodes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CodingNinjasCodes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CodingNinjasCodes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CodingNinjasCodes/subscriptions',
# ...

# %%
#watchers_count 
#forks_count
for i in d:
    if(i['fork']==False):
        print(i['name'],i['watchers_count'],i['forks_count'])
# Out:
# SmoothScrollJs 16 5
# RubyTutorial 14 9
# Python3Tutorial 5 3
# HTMLandCssNotes 12 20
# Beacathon 2 8
# JSNotes 5 6
# learnml 1 0
# RubyNotebook 2 5
# InterQues 61 148
# coderoom 4 3

# %%
###################################################
dat={'client_id':'a0dded788ce508ce9865','client_secret':'4dc37b0ab100a7caba4f34fe2a648810c0d3804a','code':'e6e404952596e8774aa7','redirect_uri':'https://www.google.com/','state':'yokb'}
req=requests.post('https://github.com/login/oauth/access_token',data=dat)
req.text
# Out:
# 'access_token=50d1b02924de30398a36fa89f4ab30eb7d192310&scope=repo&token_type=bearer'

# %%
header={'Authorization':'bearer 50d1b02924de30398a36fa89f4ab30eb7d192310'}
res=requests.get('https://api.github.com/orgs/CodingNinjasCodes/members')
d=res.json()
d
# Out:
# [{'login': 'aakash-cr7',
#   'id': 7534680,
#   'node_id': 'MDQ6VXNlcjc1MzQ2ODA=',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/7534680?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/aakash-cr7',
#   'html_url': 'https://github.com/aakash-cr7',
#   'followers_url': 'https://api.github.com/users/aakash-cr7/followers',
#   'following_url': 'https://api.github.com/users/aakash-cr7/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/aakash-cr7/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/aakash-cr7/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/aakash-cr7/subscriptions',
#   'organizations_url': 'https://api.github.com/users/aakash-cr7/orgs',
#   'repos_url': 'https://api.github.com/users/aakash-cr7/repos',
#   'events_url': 'https://api.github.com/users/aakash-cr7/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/aakash-cr7/received_events',
# ...

# %%
dat={'client_id':'a0dded788ce508ce9865','client_secret':'4dc37b0ab100a7caba4f34fe2a648810c0d3804a','code':'dcc7b9ff03db06a43330','redirect_uri':'https://www.google.com/','state':'yokb'}
req=requests.post('https://github.com/login/oauth/access_token',data=dat)
req.text
# Out:
# 'access_token=f6188a90930ab939016a4538253b72a31990944a&scope=repo&token_type=bearer'

# %%
header={'Authorization':'bearer f6188a90930ab939016a4538253b72a31990944a'}
req=requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/contributors',headers=header,params={'anon':'true'})
d=req.json()
d
#####################
# Out:
# [{'login': 'Sherawat42',
#   'id': 17741859,
#   'node_id': 'MDQ6VXNlcjE3NzQxODU5',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/17741859?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Sherawat42',
#   'html_url': 'https://github.com/Sherawat42',
#   'followers_url': 'https://api.github.com/users/Sherawat42/followers',
#   'following_url': 'https://api.github.com/users/Sherawat42/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Sherawat42/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Sherawat42/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Sherawat42/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Sherawat42/orgs',
#   'repos_url': 'https://api.github.com/users/Sherawat42/repos',
#   'events_url': 'https://api.github.com/users/Sherawat42/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Sherawat42/received_events',
# ...

# %%
#Fetch the health percentage of repository 'CodingNinjasCodes/SmoothScrollJs' in Github from Github API using OAuth(access token).
dat={'client_id':'a0dded788ce508ce9865','client_secret':'4dc37b0ab100a7caba4f34fe2a648810c0d3804a','code':'b8b6818e0f0987bb1d74','redirect_uri':'https://www.google.com/','state':'yokb'}
req=requests.post('https://github.com/login/oauth/access_token',data=dat)
req.text
# Out:
# 'access_token=d02b0efccb619f112e91cbb1ef92b1ee8e7242ef&scope=repo&token_type=bearer'

# %%
header={'Authorization':'bearer d02b0efccb619f112e91cbb1ef92b1ee8e7242ef','Accept':'application/vnd.github.black-panther-preview+json'}
req=requests.get('https://api.github.com/repos/CodingNinjasCodes/SmoothScrollJs/community/profile',headers=header)
d=req.json()
d
# Out:
# {'health_percentage': 33,
#  'description': 'Smooth Scroll for all internal links. ',
#  'documentation': 'https://codingninjascodes.github.io/SmoothScrollJs/',
#  'files': {'code_of_conduct': None,
#   'contributing': None,
#   'issue_template': None,
#   'pull_request_template': None,
#   'license': None,
#   'readme': {'url': 'https://api.github.com/repos/CodingNinjasCodes/SmoothScrollJs/contents/README.md',
#    'html_url': 'https://github.com/CodingNinjasCodes/SmoothScrollJs/blob/master/README.md'}},
#  'updated_at': '2016-11-17T01:35:06Z'}

# %%
dat={'client_id':'a0dded788ce508ce9865','client_secret':'4dc37b0ab100a7caba4f34fe2a648810c0d3804a','code':'229bb361bfbc7185106a','redirect_uri':'https://www.google.com/','state':'yokb'}
req=requests.post('https://github.com/login/oauth/access_token',data=dat)
req.text
# Out:
# 'access_token=821143ad8f20b58ce2e667642732c41a0e5bc507&scope=repo&token_type=bearer'

# %%
#Fetch the all repositories of organisation ‘fossasia’ from Github API using OAuth(access token)
header={'Authorization':'bearer 0ce44f95d05f4d3c68ae2930ed26cb60c6dfa8b0','Accept':'application/vnd.github.baptiste-preview+json','Accept':'application/vnd.github.nebula-preview+json'}
req=requests.get('https://api.github.com/orgs/fossasia/repos',headers=header)
d=req.json()
d
# Out:
# [{'id': 4132843,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTMyODQz',
#   'name': 'x-mario',
#   'full_name': 'fossasia/x-mario',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fossasia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fossasia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fossasia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fossasia/orgs',
#    'repos_url': 'https://api.github.com/users/fossasia/repos',
# ...

# %%
#e46aabab257ee1dd44bf
header={'Authorization':'bearer ddd1b5b7eb8ae131fda604967fad7eb4f70041ea'}
r=requests.get('https://api.github.com/orgs/fossasia',headers=header)
d=r.json()
d
# Out:
# {'login': 'fossasia',
#  'id': 6295529,
#  'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#  'url': 'https://api.github.com/orgs/fossasia',
#  'repos_url': 'https://api.github.com/orgs/fossasia/repos',
#  'events_url': 'https://api.github.com/orgs/fossasia/events',
#  'hooks_url': 'https://api.github.com/orgs/fossasia/hooks',
#  'issues_url': 'https://api.github.com/orgs/fossasia/issues',
#  'members_url': 'https://api.github.com/orgs/fossasia/members{/member}',
#  'public_members_url': 'https://api.github.com/orgs/fossasia/public_members{/member}',
#  'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#  'description': 'Open Technologies developed in Asia and Around the Globe',
#  'name': 'FOSSASIA',
#  'company': None,
#  'blog': 'https://fossasia.org',
#  'location': 'Singapore',
#  'email': 'fossasia@googlegroups.com',
#  'is_verified': False,
#  'has_organization_projects': False,
#  'has_repository_projects': True,
#  'public_repos': 232,
# ...

# %%
total_repos=d['public_repos']
#to calculate number of pages we have to divide it by repos on one page i.e 30
num_pages=232//30
num_pages
#so to fetch all the repositries we have to run a for loop for every page
#Fetch the all repositories of organisation ‘fossasia’ from Github API using OAuth(access token)
# Out:
# 7

# %%
#Fetch the list of contributors in the repository 'CodingNinjasCodes/JSNotes' in Github from Github API using OAuth(access token).
#021cf7ad12dec9422ca387c56af382b6bad4deaf
header={'Authorization':'bearer 021cf7ad12dec9422ca387c56af382b6bad4deaf'}
r=requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors',headers=header,params={'anon':'true'})
d=r.json()
for i in d:
    print(i['author']['login'],i['total'])
# Out:
# tushartuteja 5
# Rawal27 13
# Sherawat42 15
